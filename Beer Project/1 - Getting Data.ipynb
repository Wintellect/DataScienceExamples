# %% [markdown]
# # Getting Beer Data

# %% [markdown]
# ## Imports

# %%
import requests
from time import sleep
import pandas as pd
import numpy as np

# %% [markdown]
# ## Get Beers

# %%
key = "c96d2760fbd1bc0c6a8831b87ce86137"
beer_url = "http://api.brewerydb.com/v2/beers/?key={}&availableId=1&p={}"

beers_response = requests.get(beer_url.format(key, "1"))
beers = beers_response.json()

# %%
totalPages = beers["numberOfPages"]

beers_dict = beers["data"]

for i in range(2, totalPages + 1):
    sleep(1) # Be nice to their servers
    beers_response = requests.get(beer_url.format(key, i))
    beers = beers_response.json()
    
    beers_dict.extend(beers["data"])

# %%
df = pd.DataFrame.from_dict(beers_dict)
df.head()
# Out:
#     abv                                          available  availableId  \
# 0  6.33  {'id': 1, 'name': 'Year Round', 'description':...            1
# 1   5.6  {'id': 1, 'name': 'Year Round', 'description':...            1
# 2   6.6  {'id': 1, 'name': 'Year Round', 'description':...            1
# 3   NaN  {'id': 1, 'name': 'Year Round', 'description':...            1
# 4   4.7  {'id': 1, 'name': 'Year Round', 'description':...            1
#
#   beerVariation beerVariationId           createDate  \
# 0           NaN             NaN  2015-04-20 21:43:59
# 1           NaN             NaN  2013-04-28 20:21:56
# 2           NaN             NaN  2013-07-27 14:02:13
# 3           NaN             NaN  2012-09-29 17:22:22
# 4           NaN             NaN  2012-01-03 02:44:19
#
#                                          description foodPairings  \
# 0  Our first beer has been aptly named "633" afte...          NaN
# 1  Good, dense head retention is desirable. Light...          NaN
# 2  This medium amber beer is infused with a blend...          NaN
# 3  The stout style lends itself well to pairing w...          NaN
# 4  The true Summer Ale of Central Oregon! A Golde...          NaN
#
#                                                glass  glasswareId ...   \
# 0                                                NaN          NaN ...
# 1                                                NaN          NaN ...
# 2  {'id': 5, 'name': 'Pint', 'createDate': '2012-...          5.0 ...
# 3  {'id': 5, 'name': 'Pint', 'createDate': '2012-...          5.0 ...
# 4  {'id': 5, 'name': 'Pint', 'createDate': '2012-...          5.0 ...
#
#   servingTemperature servingTemperatureDisplay  \
# 0                NaN                       NaN
# 1                NaN                       NaN
# 2                NaN                       NaN
# 3                NaN                       NaN
# 4                NaN                       NaN
#
#                                        srm srmId    status statusDisplay  \
# 0                                      NaN   NaN  verified      Verified
# 1  {'id': 5, 'name': '5', 'hex': 'FBB123'}   5.0  verified      Verified
# 2                                      NaN   NaN  verified      Verified
# 3                                      NaN   NaN  verified      Verified
# 4                                      NaN   NaN  verified      Verified
#
#                                                style styleId  \
# 0  {'id': 25, 'categoryId': 3, 'category': {'id':...    25.0
# 1  {'id': 45, 'categoryId': 4, 'category': {'id':...    45.0
# 2  {'id': 30, 'categoryId': 3, 'category': {'id':...    30.0
# 3  {'id': 20, 'categoryId': 1, 'category': {'id':...    20.0
# 4  {'id': 36, 'categoryId': 3, 'category': {'id':...    36.0
#
#             updateDate year
# 0  2015-04-20 21:43:59  NaN
# 1  2016-05-05 14:07:35  NaN
# 2  2015-03-18 18:05:08  NaN
# 3  2015-04-24 13:24:02  NaN
# 4  2015-05-22 02:27:37  NaN
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (9670, 27)

# %%
df.columns.values
# Out:
# array(['abv', 'available', 'availableId', 'beerVariation',
#        'beerVariationId', 'createDate', 'description', 'foodPairings',
#        'glass', 'glasswareId', 'ibu', 'id', 'isOrganic', 'labels', 'name',
#        'nameDisplay', 'originalGravity', 'servingTemperature',
#        'servingTemperatureDisplay', 'srm', 'srmId', 'status',
#        'statusDisplay', 'style', 'styleId', 'updateDate', 'year'], dtype=object)

# %%
df.to_csv("./beers_raw.csv", encoding="utf-8")

# %% [markdown]
# ## Get Styles

# %%
style_url = "http://api.brewerydb.com/v2/styles/?key={}"

styles_response = requests.get(style_url.format(key))
styles = styles_response.json()

# %%
styles_dict = [[style["id"], style["name"], style["shortName"]] for style in styles["data"]]
style_df = pd.DataFrame.from_dict(styles_dict)
style_df.columns = ["id", "name", "shortName"]

style_df.head()
# Out:
#    id                            name       shortName
# 0   1  Classic English-Style Pale Ale    English Pale
# 1   2    English-Style India Pale Ale     English IPA
# 2   3                 Ordinary Bitter          Bitter
# 3   4   Special Bitter or Best Bitter  Special Bitter
# 4   5            Extra Special Bitter             ESB

# %%
style_df.to_csv("./styles_raw.csv", encoding="utf-8")

# %%
style_df = pd.read_csv("styles_raw.csv")

# %% [markdown]
# ## Clean Data

# %% [markdown]
# ### Drop unneeded columns

# %%
df = df.drop(["Unnamed: 0", "updateDate", "originalGravity", "year", "available", "glasswareId", "name", "beerVariation", "beerVariationId", "description", "foodPairings", "glass", "servingTemperatureDisplay", "style", "labels", "srm", "statusDisplay"], axis=1)
df.head()
# Out:
#     abv  availableId           createDate   ibu      id isOrganic  \
# 0  6.33            1  2015-04-20 21:43:59  25.0  ZsQEJt         N
# 1  5.60            1  2013-04-28 20:21:56  28.2  Hr5A0t         N
# 2  6.60            1  2013-07-27 14:02:13  45.0  5UcMBc         N
# 3   NaN            1  2012-09-29 17:22:22   NaN  54rSgo         N
# 4  4.70            1  2012-01-03 02:44:19  26.0  b7WWL6         N
#
#                           nameDisplay servingTemperature  srmId    status  \
# 0             "633" American Pale Ale                NaN    NaN  verified
# 1                "God Country" Kolsch                NaN    5.0  verified
# 2                      "Ignition" IPA                NaN    NaN  verified
# 3        "Jemmy Dean" Breakfast Stout                NaN    NaN  verified
# 4  "Mike Saw a Sasquatch" Session Ale                NaN    NaN  verified
#
#    styleId
# 0     25.0
# 1     45.0
# 2     30.0
# 3     20.0
# 4     36.0

# %% [markdown]
# ### Change `styleId` type from float to integer.

# %%
df = pd.read_csv("beers_raw.csv")

# %%
df["styleId"].isnull().values.any()
# Out:
# True

# %%
df.dropna(subset=["styleId"], inplace=True)

# %%
df["styleId"].isnull().sum()
# Out:
# 0

# %%
df["styleId"] = df["styleId"].astype(int)

# %%
df["ibu"].isnull().values.any()
# Out:
# True

# %%
print(df["ibu"].isnull().sum())
print(df.shape)
# Out:
# 3974
# (9624, 11)

# %%
ibu_mean = round(np.mean(df["ibu"]), 1)

# %%
df["ibu"] = df["ibu"].fillna(ibu_mean)

# %%
df["ibu"].isnull().values.any()
# Out:
# 9651   5.40            1  2012-10-23 13:55:33  65.0  TJFb04         N
# 9652  10.00            1  2017-05-08 13:08:35  60.0  CWrotz         N
# 9653   7.24            1  2014-10-11 20:00:52  70.2  htoUmg         N
# 9654   5.00            1  2015-03-12 19:17:47  39.6  Zie6mU         N
# 9655   4.90            1  2012-05-01 19:03:02  39.6  2lV08H         N
# 9656   7.20            1  2012-01-03 02:44:34  39.6  erOQsC         N
# 9657   6.20            1  2012-01-03 02:44:34  50.0  SPClNd         N
# 9658   5.50            1  2013-01-24 12:02:42  39.6  3wUBDX         N
# 9659   5.00            1  2017-08-02 14:53:57  15.0  bBUdSl         N
# 9660   4.50            1  2014-11-12 16:41:47  39.6  pxKs6k         N
# 9661   9.30            1  2015-02-03 17:12:23  45.0  mtgPmZ         N
# 9662   8.00            1  2015-08-10 15:47:50  39.6  KcYsSY         N
# 9663   5.30            1  2016-05-21 10:39:02  39.6  OI7zts         N
# 9664   4.90            1  2016-05-21 10:38:17  39.6  lyPBkR         N
# 9665   4.00            1  2017-06-26 15:19:32  22.0  kWSNVk         N
# 9666   5.10            1  2016-04-04 19:34:17  39.6  6BH1m1         N
# 9667   5.60            1  2015-12-31 13:47:57  39.6  wBHeYa         N
# 9668   6.90            1  2015-05-11 13:50:01  68.0  JOETmw         Y
# 9669   3.80            1  2012-01-03 02:44:34  39.6  IIIhSR         N
#
#                                 nameDisplay servingTemperature  srmId  \
# 0                   "633" American Pale Ale                NaN    NaN
# 1                      "God Country" Kolsch                NaN    5.0
# 2                            "Ignition" IPA                NaN    NaN
# 3              "Jemmy Dean" Breakfast Stout                NaN    NaN
# 4        "Mike Saw a Sasquatch" Session Ale                NaN    NaN
# 5                                 "My" Bock                NaN    NaN
# 6                    "OG" Original Gangster                NaN    NaN
# 7                 "Sneaky Devil" Double IPA                NaN    NaN
# 8               "Whistleblower" Belgian Wit                NaN    NaN
# 9                             #2 Strong Ale                NaN    NaN
# 10                                       #9               cold    9.0
# 11                        #Hashtag Hops IPA                NaN    NaN
# 12                                  #KoLSCH          very_cold    3.0
# 13                          '400' Honey Ale                NaN    NaN
# 14                           '67 Blonde Ale                NaN    NaN
# 15                   (306) URBAN WHEAT BEER               cold    9.0
# 16                        (416) Local Lager               cold    NaN
# 17                                (512) IPA               cold    8.0
# 18                               (512) Pale               cold    7.0
# 19                                (512) Wit               cold    5.0
# 20                                    (916)               cool    8.0
# 21                                 (S)Wheat                NaN    NaN
# 22                  (Take The) Causeway IPA                NaN    NaN
# 23                              .58 Caliber                NaN    NaN
# 24                                     .999               cold    NaN
# 25                     077XX India Pale Ale                NaN    5.0
# 26                            1 North Lager                NaN    NaN
# 27                     10 Speed Hoppy Wheat                NaN    NaN
# 28                                   10 Ton                NaN   34.0
# 29                            10-Point Bock                NaN   13.0
# ...                                     ...                ...    ...
# 9640                                Yum Yum                NaN    NaN
# 9641                          Yuzu Pale Ale                NaN    NaN
# 9642                      Zack Morgan's IPA                NaN   10.0
# 9643                              Zarabanda                NaN    NaN
# 9644               Zatte Amsterdamse Tripel               cool    NaN
# 9645                                 Zeke's                NaN    7.0
# 9646                             Zenith IPA                NaN    NaN
# 9647                        Zeno's Pale Ale                NaN    NaN
# 9648                                 ZEPHYR               cold    NaN
# 9649                      Zephyr Golden Ale                NaN    NaN
# 9650                       Zephyrus Pilsner                NaN    NaN
# 9651                              Zero Hour                NaN   33.0
# 9652                                 Zestig                NaN    NaN
# 9653                   Zeus Will Smite Thee               cold   12.0
# 9654                                Zingari                NaN    NaN
# 9655                               Zlatorog                NaN    NaN
# 9656                                    Zoe                NaN    NaN
# 9657                            Zombie Dust               cold   11.0
# 9658             Zombie Killer Cherry Cyser                NaN    NaN
# 9659                            Zondagskind                NaN    NaN
# 9660                            Zulu Blonde                NaN    NaN
# 9661  Zumbar Chocolate Coffe Imperial Stout                NaN    NaN
# 9662                       Zundert Trappist               cool    NaN
# 9663                     Zwergenbräu Export                NaN    NaN
# 9664                   Zwergenbräu Pilsener                NaN    NaN
# 9665                            Zwickelbier                NaN    NaN
# 9666                             Zwickl Max                NaN    NaN
# 9667                            Zywiec Beer                NaN    NaN
# 9668                            ‘39 Red IPA                NaN   15.0
# 9669                  “O!” Gold Light Lager                NaN    NaN
#
#         status  styleId
# 0     verified       25
# 1     verified       45
# 2     verified       30
# 3     verified       20
# 4     verified       36
# 5     verified       88
# 6     verified       25
# 7     verified       31
# 8     verified       65
# 9     verified       14
# 10    verified       25
# 11    verified       30
# 12    verified       45
# 13    verified       36
# 14    verified       36
# 15    verified       65
# 16    verified       93
# 17    verified       30
# 18    verified       25
# 19    verified       65
# 20    verified       25
# 21    verified      124
# 22    verified       30
# 23    verified       30
# 24    verified        2
# 25    verified       31
# 26    verified       80
# 27    verified      113
# 28    verified       21
# 29    verified       88
# ...        ...      ...
# 9640  verified      108
# 9641  verified       25
# 9642  verified       30
# 9643  verified       72
# 9644  verified       59
# 9645  verified       25
# 9646  verified       30
# 9647  verified       25
# 9648  verified       30
# 9649  verified       25
# 9650  verified       98
# 9651  verified       41
# 9652  verified       31
# 9653  verified       30
# 9654  verified       65
# 9655  verified      106
# 9656  verified       32
# 9657  verified       25
# 9658  verified      148
# 9659  verified       48
# 9660  verified       36
# 9661  verified       43
# 9662  verified       60
# 9663  verified       79
# 9664  verified       75
# 9665  verified       75
# 9666  verified       92
# 9667  verified       73
# 9668  verified       30
# 9669  verified       94
#
# [9624 rows x 11 columns]

# %% [markdown]
# ### Merge data frames

# %%
df = df.merge(style_df, how="inner", left_on="styleId", right_on="id")

# %% [markdown]
# ### Clean merged data frame

# %%
df.columns.values
# Out:
# array(['abv', 'availableId', 'createDate', 'ibu', 'id_x', 'isOrganic',
#        'nameDisplay', 'servingTemperature', 'srmId', 'status', 'styleId',
#        'styleName', 'Unnamed: 0', 'id_y', 'name', 'shortName'], dtype=object)

# %%
df = df.drop(["availableId", "Unnamed: 0", "id_y", "shortName"], axis=1)

# %%
df = df.rename(columns={"id_x": "id", "name": "styleName"})

# %%
df.to_csv("beers_clean.csv")
